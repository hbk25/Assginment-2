# %% [markdown]
# <a href="https://colab.research.google.com/github/hbk25/Assginment-2/blob/main/Covid19_prediction_CP2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1) IMPORTING LIBRARIES

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D,Dropout, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 2) CLONING DATASET

# %%
# CLONING THE DATASET FROM THE GITHUB REPOSITORY
# !git clone https://github.com/RishitToteja/Chext-X-ray-Images-Data-Set.git
# Out:
# Cloning into 'Chext-X-ray-Images-Data-Set'...
# remote: Enumerating objects: 2319, done.
# remote: Total 2319 (delta 0), reused 0 (delta 0), pack-reused 2319
# Receiving objects: 100% (2319/2319), 1.31 GiB | 36.84 MiB/s, done.
# Checking out files: 100% (2296/2296), done.

# %%
import os

main_dir = "/content/Chext-X-ray-Images-Data-Set/DataSet/Data"

# SETTING TRAIN AND TEST DIRECTORY
train_dir = os.path.join(main_dir, "train")
test_dir = os.path.join(main_dir, "test")

#SETING DIRECTORY FOR COVID AND NORMAL IMAGES DIRECTORY
train_covid_dir = os.path.join(train_dir, "COVID19")
train_normal_dir = os.path.join(train_dir, "NORMAL")

test_covid_dir = os.path.join(test_dir, "COVID19")
test_normal_dir = os.path.join(test_dir, "NORMAL")

# %%
# MAKING SEPERATE FILES : 
train_covid_names = os.listdir(train_covid_dir)
train_normal_names = os.listdir(train_normal_dir)

test_covid_names = os.listdir(test_covid_dir)
test_normal_names = os.listdir(test_normal_dir)

# %% [markdown]
# # 3) PERFORMING DATA VISUALIZATION

# %%
import matplotlib.image as mpimg

rows = 4
columns = 4

fig = plt.gcf()
fig.set_size_inches(12,12)

covid_img = [os.path.join(train_covid_dir, filename) for filename in train_covid_names[0:8]]
normal_img = [os.path.join(train_normal_dir, filename) for filename in train_normal_names[0:8]]

print(covid_img)
print(normal_img)

merged_img = covid_img + normal_img

for i, img_path in enumerate(merged_img):
  title = img_path.split("/", 6)[6]
  plot = plt.subplot(rows, columns, i+1)
  plot.axis("Off")
  img = mpimg.imread(img_path)
  plot.set_title(title, fontsize = 11)
  plt.imshow(img, cmap= "gray")

plt.show()
# Out:
# ['/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID-19 (5).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID19(146).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID19(471).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID19(94).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID-19 (35).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID19(0).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID19(292).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/COVID19/COVID19(546).jpg']
# ['/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(1177).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(946).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(451).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(216).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(84).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(90).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(1039).jpg', '/content/Chext-X-ray-Images-Data-Set/DataSet/Data/train/NORMAL/NORMAL(1059).jpg']

# %% [markdown]
# # 4) DATA PREPROCESSING AND AUGMENTATION

# %%
2.# CREATING TRAINING, TESTING AND VALIDATION BATCHES

dgen_train = ImageDataGenerator(rescale = 1./255,
                                validation_split = 0.2,
                                zoom_range = 0.2,
                                horizontal_flip = True)

dgen_validation = ImageDataGenerator(rescale = 1./255,
                                     )

dgen_test = ImageDataGenerator(rescale = 1./255,
                              )

train_generator = dgen_train.flow_from_directory(train_dir,
                                                 target_size = (150, 150), 
                                                 subset = 'training',
                                                 batch_size = 32,
                                                 class_mode = 'binary')
validation_generator = dgen_train.flow_from_directory(train_dir,
                                                      target_size = (150, 150), 
                                                      subset = "validation", 
                                                      batch_size = 32, 
                                                      class_mode = "binary")
test_generator = dgen_test.flow_from_directory(test_dir,
                                               target_size = (150, 150), 
                                               batch_size = 32, 
                                               class_mode = "binary")
# Out:
# Found 1449 images belonging to 2 classes.
# Found 362 images belonging to 2 classes.
# Found 484 images belonging to 2 classes.

# %%
print("Class Labels are: ", train_generator.class_indices)
print("Image shape is : ", train_generator.image_shape)
# Out:
# Class Labels are:  {'COVID19': 0, 'NORMAL': 1}
# Image shape is :  (150, 150, 3)

# %% [markdown]
# # 5) BUILDING CONVOLUTIONAL NEURAL NETWORK MODEL

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D

model = Sequential()

# 1) CONVOLUTIONAL LAYER - 1
model.add(Conv2D(32, (5,5), padding = "same", activation = "relu", input_shape = train_generator.image_shape))

# 2) POOLING LAYER - 1
model.add(MaxPooling2D(pool_size=(2,2)))

# 3) DROPOUT LAYER -2
model.add(Dropout(0.5))

# 4) CONVOLUTIONAL LAYER - 2
model.add(Conv2D(64, (5,5), padding = "same", activation = "relu"))

# 5) POOLING LAYER - 2
model.add(MaxPooling2D(pool_size=(2,2)))

# 6) DROPOUT LAYER - 2
model.add(Dropout(0.5))

# 7) FLATTENING LAYER TO 2D SHAPE
model.add(Flatten())

# 8) ADDING A DENSE LAYER
model.add(Dense(256, activation = 'relu'))

# 9 DROPOUT LAYER - 3
model.add(Dropout(0.5))

# 10) FINAL OUTPUT LAYER
model.add(Dense(1, activation = 'sigmoid'))

### PRINTING MODEL SUMMARY
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 150, 150, 32)      2432
#
#  max_pooling2d (MaxPooling2D  (None, 75, 75, 32)       0
#  )
#
#  dropout (Dropout)           (None, 75, 75, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 75, 75, 64)        51264
#
#  max_pooling2d_1 (MaxPooling  (None, 37, 37, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 37, 37, 64)        0
#
#  flatten (Flatten)           (None, 87616)             0
#
#  dense (Dense)               (None, 256)               22429952
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 22,483,905
# Trainable params: 22,483,905
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 6) COMPILING AND TRAINING THE NEURAL NETWORK MODEL

# %%
# COMPILING THE MODEL

model.compile(Adam(learning_rate = 0.001), loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
# TRAINING THE MODEL
history = model.fit(train_generator, 
                    epochs = 35, 
                    validation_data = validation_generator)
# Out:
# Epoch 1/35
# 46/46 [==============================] - 60s 1s/step - loss: 1.3690 - accuracy: 0.7074 - val_loss: 0.3956 - val_accuracy: 0.8785
# Epoch 2/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.2727 - accuracy: 0.8944 - val_loss: 0.1936 - val_accuracy: 0.9530
# Epoch 3/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.1894 - accuracy: 0.9324 - val_loss: 0.2148 - val_accuracy: 0.9586
# Epoch 4/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.1735 - accuracy: 0.9441 - val_loss: 0.2111 - val_accuracy: 0.9448
# Epoch 5/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.1585 - accuracy: 0.9503 - val_loss: 0.1218 - val_accuracy: 0.9613
# Epoch 6/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.1316 - accuracy: 0.9503 - val_loss: 0.1295 - val_accuracy: 0.9448
# Epoch 7/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.1425 - accuracy: 0.9510 - val_loss: 0.1480 - val_accuracy: 0.9586
# Epoch 8/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.1433 - accuracy: 0.9462 - val_loss: 0.1218 - val_accuracy: 0.9586
# Epoch 9/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.1264 - accuracy: 0.9593 - val_loss: 0.1025 - val_accuracy: 0.9641
# Epoch 10/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.1230 - accuracy: 0.9579 - val_loss: 0.0929 - val_accuracy: 0.9669
# Epoch 11/35
# 46/46 [==============================] - 46s 1s/step - loss: 0.1149 - accuracy: 0.9620 - val_loss: 0.0950 - val_accuracy: 0.9724
# Epoch 12/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.1399 - accuracy: 0.9503 - val_loss: 0.1019 - val_accuracy: 0.9669
# Epoch 13/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.1148 - accuracy: 0.9655 - val_loss: 0.1531 - val_accuracy: 0.9309
# Epoch 14/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.1265 - accuracy: 0.9586 - val_loss: 0.0886 - val_accuracy: 0.9696
# Epoch 15/35
# 46/46 [==============================] - 46s 1s/step - loss: 0.1113 - accuracy: 0.9641 - val_loss: 0.0920 - val_accuracy: 0.9696
# Epoch 16/35
# 46/46 [==============================] - 46s 1s/step - loss: 0.0912 - accuracy: 0.9717 - val_loss: 0.1002 - val_accuracy: 0.9586
# Epoch 17/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.1040 - accuracy: 0.9593 - val_loss: 0.0887 - val_accuracy: 0.9669
# Epoch 18/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.1027 - accuracy: 0.9655 - val_loss: 0.0968 - val_accuracy: 0.9669
# Epoch 19/35
# 46/46 [==============================] - 46s 1s/step - loss: 0.1021 - accuracy: 0.9593 - val_loss: 0.0747 - val_accuracy: 0.9779
# Epoch 20/35
# 46/46 [==============================] - 46s 1s/step - loss: 0.0990 - accuracy: 0.9655 - val_loss: 0.0696 - val_accuracy: 0.9696
# Epoch 21/35
# 46/46 [==============================] - 46s 1s/step - loss: 0.0917 - accuracy: 0.9731 - val_loss: 0.0751 - val_accuracy: 0.9751
# Epoch 22/35
# 46/46 [==============================] - 46s 1s/step - loss: 0.1015 - accuracy: 0.9634 - val_loss: 0.0861 - val_accuracy: 0.9724
# Epoch 23/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.1135 - accuracy: 0.9614 - val_loss: 0.1061 - val_accuracy: 0.9475
# Epoch 24/35
# 46/46 [==============================] - 48s 1s/step - loss: 0.1068 - accuracy: 0.9641 - val_loss: 0.1233 - val_accuracy: 0.9503
# Epoch 25/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.1019 - accuracy: 0.9689 - val_loss: 0.0788 - val_accuracy: 0.9724
# Epoch 26/35
# 46/46 [==============================] - 46s 1s/step - loss: 0.0796 - accuracy: 0.9758 - val_loss: 0.0627 - val_accuracy: 0.9834
# Epoch 27/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.0746 - accuracy: 0.9765 - val_loss: 0.0717 - val_accuracy: 0.9807
# Epoch 28/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.0659 - accuracy: 0.9800 - val_loss: 0.0589 - val_accuracy: 0.9751
# Epoch 29/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.0701 - accuracy: 0.9772 - val_loss: 0.0674 - val_accuracy: 0.9834
# Epoch 30/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.0660 - accuracy: 0.9821 - val_loss: 0.0591 - val_accuracy: 0.9834
# Epoch 31/35
# 46/46 [==============================] - 46s 1s/step - loss: 0.0692 - accuracy: 0.9786 - val_loss: 0.0577 - val_accuracy: 0.9807
# Epoch 32/35
# 46/46 [==============================] - 46s 1s/step - loss: 0.0559 - accuracy: 0.9814 - val_loss: 0.0514 - val_accuracy: 0.9751
# Epoch 33/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.0764 - accuracy: 0.9752 - val_loss: 0.0566 - val_accuracy: 0.9751
# Epoch 34/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.0627 - accuracy: 0.9752 - val_loss: 0.0439 - val_accuracy: 0.9890
# Epoch 35/35
# 46/46 [==============================] - 47s 1s/step - loss: 0.0544 - accuracy: 0.9848 - val_loss: 0.0595 - val_accuracy: 0.9807

# %% [markdown]
# # 7) PERFORMING EVALUATION

# %%
# KEYS OF HISTORY OBJECT
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# PLOT GRAPH BETWEEN TRAINING AND VALIDATION LOSS
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Training', 'Validation'])
plt.title("Training and validation losses")
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
# PLOT GRAPH BETWEEN TRAINING AND VALIDATION ACCURACY
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['Training', 'Validation'])
plt.title("Training and validation accuracy")
plt.xlabel('epoch')
# Out:
# Text(0.5, 0, 'epoch')

# %%
# GETTING TEST ACCURACY AND LOSS

test_loss, test_acc = model.evaluate(test_generator)
print("Test Set Loss : ", test_loss)
print("Test Set Accuracy : ", test_acc)
# Out:
# 16/16 [==============================] - 10s 626ms/step - loss: 0.0710 - accuracy: 0.9773
# Test Set Loss :  0.07103902846574783
# Test Set Accuracy :  0.9772727489471436

# %% [markdown]
# # 9) PREDICTION ON NEW DATA (UPLOAD FILES)

# %%
from google.colab import files
from keras.preprocessing import image
import numpy as np
def callfun():
  uploaded = files.upload()

  for filename in uploaded.keys():
    img_path = '/content/' + filename
    img = image.load_img(img_path, target_size = (150,150))
    images = image.img_to_array(img)
    images = np.expand_dims(images, axis = 0)
    prediction = model.predict(images)
  
    if prediction == 0:
      print("The report is COVID-19 Positive")
    else:
      print("The report is COVID-19 Negative")

# %%
model.save("model.h5")

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
callfun()
# Out:
#      <input type="file" id="files-43265cb1-10de-483a-9070-d67dc1468e1c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-43265cb1-10de-483a-9070-d67dc1468e1c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving chest xray (2).jpeg to chest xray (2).jpeg
# The report is COVID-19 Positive

# %%
callfun()
# Out:
#      <input type="file" id="files-47435534-a132-4949-b195-658d97877d99" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-47435534-a132-4949-b195-658d97877d99">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving chest xray (3).jpeg to chest xray (3).jpeg
# The report is COVID-19 Negative
